# %% [markdown]
# # Joe Gaspari
#
# Through the addition of sentiment analysis and contribution analysis we hope to model the trends of users and how they change over time. We also would like to identify major contributors to discussions.

# %%
# import posts as ps

# df = ps.load_Q()

# df2 = ps.load_clean_Q( df )
# display(df2)
# display(df2.info())

# df2.to_csv("Data2/FinalData/qdata.csv")
# Out:
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/posts.py:24: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = ( pd.read_csv("Data2/Questions.csv")
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/posts.py:438: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merged = merged.drop("Tags_x", 1)
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/posts.py:439: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merged = merged.drop("Body", 1)
#              Id  AnswerCount            CreationDate  OwnerUserId  Score  \
# 0       1786915            3 2009-11-23 23:54:33.523       178189      0
# 1       1786917            2 2009-11-23 23:55:14.417       160359     55
# ...

# %%
# ansers = ps.load_A()
# answers = ps.load_clean_A(ansers)
# display(answers)

# answers.to_csv("Data2/FinalData/adata.csv")
# Out:
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/posts.py:46: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df2 = ( pd.read_csv("Data2/Answers.csv")
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/posts.py:465: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merged = merged.drop("Body", 1)
#              Id  CommentCount            CreationDate  OwnerUserId  ParentId  \
# 0       1786916             2 2009-11-23 23:55:06.080        92248   1786198
# 1       1786918             0 2009-11-23 23:55:19.783       108207   1786735
# 2       1786920             1 2009-11-23 23:56:03.457        47721   1786894
# 3       1776401             0 2009-11-21 19:03:19.530       216170   1104960
# 4       1776402             2 2009-11-21 19:03:24.053        26428   1776073
# ...

# %%
import comDefs as cd

comments = cd.load_comm()
comments = cd.load_comments_data( comments)
display(comments)

comments.to_csv("Data2/FinalData/cdata.csv")
# Out:
# /Users/joegaspari/Documents/Documents/Year2/S1/COSC 329/Project/comDefs.py:383: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   merged = merged.drop("Text", 1)
#               Id            CreationDate    PostId  Score      UserId  \
# 0         176223 2008-12-04 15:39:17.380    144748      0      1323.0
# 1         176224 2008-12-04 15:39:32.713    341016      0        29.0
# 2         176226 2008-12-04 15:40:15.893    340669      0     15906.0
# 3         176227 2008-12-04 15:40:20.620    334469      1      6910.0
# 4         176229 2008-12-04 15:40:39.700    340731      0     36845.0
# ...          ...                     ...       ...    ...         ...
# 51520  119741638 2021-05-28 18:46:01.747  67744055      0  15339544.0
# 51521  119741639 2021-05-28 18:46:04.450  67744004      0  15820861.0
# 51522  119741640 2021-05-28 18:46:04.560  67697379      0   5863650.0
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19811 entries, 0 to 19810
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            19811 non-null  int64
#  1   AnswerCount   19811 non-null  int64
#  2   Body          19811 non-null  object
#  3   CreationDate  19811 non-null  datetime64[ns]
#  4   OwnerUserId   19811 non-null  int64
#  5   Score         19811 non-null  int64
#  6   Tags_x        19811 non-null  object
#  7   ViewCount     19811 non-null  int64
#  8   Text          19811 non-null  object
#  9   neg           19811 non-null  float64
#  10  neu           19811 non-null  float64
#  11  pos           19811 non-null  float64
#  12  Tags_y        19811 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(4)
# memory usage: 2.0+ MB
# None

# %%
# Out:
# {'framework', 'c', 'entity', 'wcf', "'"}

# %%
# Out:
# {'c'}
